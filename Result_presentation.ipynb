# %% [markdown]
# # 4 SSVEP frequencies

# %% [markdown]
# ### EEGClassifier 42 kb, 10.5K parameters

# %%
from Model_Trainer import run_multiple_models
from Models_1D import TCNModel_withBase
from Dataset_torch import EEGDataset_with_filters

models = [TCNModel_withBase]

shared_parameters_ssvep = {
    "data_path": "datasets/numpy/ssvep_4_nofilter_GMCGA_no01_4labels_250hz_1.5_window_size.npz", 
    
    "DATASET_CLASS": EEGDataset_with_filters,
    
    "NOTCH_50": True,         
    "OCCIPITAL_SLICE": slice(0, 8), 
    
    "MAX_TIME": "00:01:00:00",
    "MODEL_KWARGS": {
        "in_channels": 8, 
        "num_classes": 4,
        "class_labels": [10.5, 12.0, 15.2, 18.1],
        "class_weights": [1.0, 1.0, 1.0, 1.0], 
    },
    
    "skip_training": True,
    "LOAD_CHECKPOINT": "logs/TCNModel_withBase/version_12_4_best_1h_GMCGA_no01_4labels/checkpoints/best-11408-val_acc=0.948.ckpt",
}
results, test_loader = run_multiple_models(models, shared_parameters_ssvep)
# Out:
# Loading data from: datasets/numpy/ssvep_4_nofilter_GMCGA_no01_4labels_250hz_1.5_window_size.npz
# Data loaded: X=(1576, 8, 375), y=(1576,)
# Dataset split: Train=1103, Val=236, Test=237
# Dataloaders ready
#
# Processing  TCNModel_withBase...
#
# Loading model from checkpoint instead of training:
#   logs/TCNModel_withBase/version_12_4_best_1h_GMCGA_no01_4labels/checkpoints/best-11408-val_acc=0.948.ckpt
#   | Name      | Type                      | Params | Mode
# ----------------------------------------------------------------
# 0 | train_acc | MulticlassAccuracy        | 0      | train
# 1 | val_acc   | MulticlassAccuracy        | 0      | train
# 2 | test_acc  | MulticlassAccuracy        | 0      | train
# 3 | test_cm   | MulticlassConfusionMatrix | 0      | train
# 4 | tcn       | Sequential                | 10.4 K | train
# 5 | head      | Linear                    | 132    | train
# ----------------------------------------------------------------
# 10.5 K    Trainable params
# 0         Non-trainable params
# 10.5 K    Total params
# 0.042     Total estimated model params size (MB)
# 18        Modules in train mode
# 0         Modules in eval mode
# Class 10.5 accuracy: 0.983
# Class 12.0 accuracy: 0.953
# Class 15.2 accuracy: 0.982
# Class 18.1 accuracy: 0.966
# TCNModel_withBase: Test accuracy = 0.970
#
# Plotting TCNModel_withBase: Test Accuracy = 0.970
# All models processed successfully!

# %% [markdown]
# ### TCN 175 kb, 43.7 K parameters

# %%
from Model_Trainer import run_multiple_models
from Models_1D import TCNModel_v1_outch64_GELU_head2
from Dataset_torch import EEGDataset_with_filters

models = [
    TCNModel_v1_outch64_GELU_head2,
]

shared_parameters_ssvep = {
    "data_path": "datasets/numpy/ssvep_4_nofilter_GMCGA_no01_4labels_250hz_1.5_window_size.npz",
    
    "DATASET_CLASS": EEGDataset_with_filters,
    
    "NOTCH_50": True,         
    "OCCIPITAL_SLICE": slice(0, 8), 
    
    "MAX_TIME": "00:00:40:00",
    "MODEL_KWARGS": {
        "in_channels": 8, 
        
        "num_classes": 4,
        "class_labels": [10.5, 12.0, 15.2, 18.1],
        "class_weights": [1.0, 1.0, 1.0, 1.0],
    },
  
    "skip_training": True,
    # "LOAD_CHECKPOINT": "logs/TCNModel_v1_outch64_GELU_head2/version_2_958/checkpoints/best-6561-val_acc=0.962.ckpt",    # 40min    
    # "LOAD_CHECKPOINT": "logs/TCNModel_v1_outch64_GELU_head2/version_3_958_1h/checkpoints/best-9708-val_acc=0.975.ckpt",    # 1h 
    "LOAD_CHECKPOINT": "logs/TCNModel_v1_outch64_GELU_head2/version_4_979_1.5/checkpoints/best-135-val_acc=0.970.ckpt",    # 1h 
}
results, test_loader = run_multiple_models(models, shared_parameters_ssvep)
# Out:
# Loading data from: datasets/numpy/ssvep_4_nofilter_GMCGA_no01_4labels_250hz_1.5_window_size.npz
# Data loaded: X=(1576, 8, 375), y=(1576,)
# Dataset split: Train=1103, Val=236, Test=237
# Dataloaders ready
#
# Processing  TCNModel_v1_outch64_GELU_head2...
#
# Loading model from checkpoint instead of training:
#   logs/TCNModel_v1_outch64_GELU_head2/version_4_979_1.5/checkpoints/best-135-val_acc=0.970.ckpt
#   | Name      | Type                      | Params | Mode
# ----------------------------------------------------------------
# 0 | train_acc | MulticlassAccuracy        | 0      | train
# 1 | val_acc   | MulticlassAccuracy        | 0      | train
# 2 | test_acc  | MulticlassAccuracy        | 0      | train
# 3 | test_cm   | MulticlassConfusionMatrix | 0      | train
# 4 | tcn       | Sequential                | 39.2 K | train
# 5 | head      | Sequential                | 4.5 K  | train
# ----------------------------------------------------------------
# 43.7 K    Trainable params
# 0         Non-trainable params
# 43.7 K    Total params
# 0.175     Total estimated model params size (MB)
# 22        Modules in train mode
# 0         Modules in eval mode
# Class 10.5 accuracy: 0.983
# Class 12.0 accuracy: 0.984
# Class 15.2 accuracy: 0.982
# Class 18.1 accuracy: 0.966
# TCNModel_v1_outch64_GELU_head2: Test accuracy = 0.979
#
# Plotting TCNModel_v1_outch64_GELU_head2: Test Accuracy = 0.979
# All models processed successfully!

# %% [markdown]
# ### TCN small 24 kb, 5.9 K parameters

# %%
from Model_Trainer import run_multiple_models
from Dataset_torch import EEGDataset_with_filters
from Random_models import TCNModel_v1_outch64_GELU_head2_small
                          
models = [TCNModel_v1_outch64_GELU_head2_small]

shared_parameters_ssvep = {
    "data_path": "datasets/numpy/ssvep_4_nofilter_GMCGA_no01_4labels_250hz_1.5_window_size.npz",
    
    "DATASET_CLASS": EEGDataset_with_filters,
    
    "NOTCH_50": True,         
    "OCCIPITAL_SLICE": slice(0, 8), 
    
    "MAX_TIME": "00:01:00:00",
    "MODEL_KWARGS": {
        "in_channels": 8, 
        
        "num_classes": 4,
        "class_labels": [10.5, 12, 15.2, 18.1],
        "class_weights": [1.0, 1.0, 1.0, 1.0],
    },
    
    "skip_training": True,
    "LOAD_CHECKPOINT": "logs/TCNModel_v1_outch64_GELU_head2_small/version_0_4_954_1h/checkpoints/best-10840-val_acc=0.953.ckpt",   
}
results, test_loader = run_multiple_models(models, shared_parameters_ssvep)
# Out:
# Loading data from: datasets/numpy/ssvep_4_nofilter_GMCGA_no01_4labels_250hz_1.5_window_size.npz
# Data loaded: X=(1576, 8, 375), y=(1576,)
# Dataset split: Train=1103, Val=236, Test=237
# Dataloaders ready
#
# Processing  TCNModel_v1_outch64_GELU_head2_small...
#
# Loading model from checkpoint instead of training:
#   logs/TCNModel_v1_outch64_GELU_head2_small/version_0_4_954_1h/checkpoints/best-10840-val_acc=0.953.ckpt
#   | Name      | Type                      | Params | Mode
# ----------------------------------------------------------------
# 0 | train_acc | MulticlassAccuracy        | 0      | train
# 1 | val_acc   | MulticlassAccuracy        | 0      | train
# 2 | test_acc  | MulticlassAccuracy        | 0      | train
# 3 | test_cm   | MulticlassConfusionMatrix | 0      | train
# 4 | tcn       | Sequential                | 4.5 K  | train
# 5 | head      | Sequential                | 1.4 K  | train
# ----------------------------------------------------------------
# 5.9 K     Trainable params
# 0         Non-trainable params
# 5.9 K     Total params
# 0.024     Total estimated model params size (MB)
# 28        Modules in train mode
# 0         Modules in eval mode
# Class 10.5 accuracy: 0.983
# Class 12 accuracy: 0.938
# Class 15.2 accuracy: 0.965
# Class 18.1 accuracy: 0.931
# TCNModel_v1_outch64_GELU_head2_small: Test accuracy = 0.954
#
# Plotting TCNModel_v1_outch64_GELU_head2_small: Test Accuracy = 0.954
# All models processed successfully!

# %% [markdown]
# ### TCN smallest 9 kb, 2.4 K parameters

# %%
from Model_Trainer import run_multiple_models
from Dataset_torch import EEGDataset_with_filters
from Random_models import TCNModel_v1_outch64_GELU_head2_smallest
                          
models = [TCNModel_v1_outch64_GELU_head2_smallest]

shared_parameters_ssvep = {
    "data_path": "datasets/numpy/ssvep_4_nofilter_GMCGA_no01_4labels_250hz_1.5_window_size.npz",
    
    "DATASET_CLASS": EEGDataset_with_filters,
    
    "NOTCH_50": True,         
    "OCCIPITAL_SLICE": slice(0, 8), 
    
    "MAX_TIME": "00:01:00:00",
    "MODEL_KWARGS": {
        "in_channels": 8, 
        
        "num_classes": 4,
        "class_labels": [10.5, 12, 15.2, 18.1],
        "class_weights": [1.0, 1.0, 1.0, 1.0],
    },
    
    "skip_training": True,
    "LOAD_CHECKPOINT": "logs/TCNModel_v1_outch64_GELU_head2_smallest/version_0_4_928_1h/checkpoints/best-12358-val_acc=0.928.ckpt",   
}
results, test_loader = run_multiple_models(models, shared_parameters_ssvep)
# Out:
# Loading data from: datasets/numpy/ssvep_4_nofilter_GMCGA_no01_4labels_250hz_1.5_window_size.npz
# Data loaded: X=(1576, 8, 375), y=(1576,)
# Dataset split: Train=1103, Val=236, Test=237
# Dataloaders ready
#
# Processing  TCNModel_v1_outch64_GELU_head2_smallest...
#
# Loading model from checkpoint instead of training:
#   logs/TCNModel_v1_outch64_GELU_head2_smallest/version_0_4_928_1h/checkpoints/best-12358-val_acc=0.928.ckpt
#   | Name      | Type                      | Params | Mode
# ----------------------------------------------------------------
# 0 | train_acc | MulticlassAccuracy        | 0      | train
# 1 | val_acc   | MulticlassAccuracy        | 0      | train
# 2 | test_acc  | MulticlassAccuracy        | 0      | train
# 3 | test_cm   | MulticlassConfusionMatrix | 0      | train
# 4 | tcn       | Sequential                | 1.5 K  | train
# 5 | head      | Sequential                | 852    | train
# ----------------------------------------------------------------
# 2.4 K     Trainable params
# 0         Non-trainable params
# 2.4 K     Total params
# 0.009     Total estimated model params size (MB)
# 31        Modules in train mode
# 0         Modules in eval mode
# Class 10.5 accuracy: 0.983
# Class 12 accuracy: 0.922
# Class 15.2 accuracy: 0.895
# Class 18.1 accuracy: 0.914
# TCNModel_v1_outch64_GELU_head2_smallest: Test accuracy = 0.928
#
# Plotting TCNModel_v1_outch64_GELU_head2_smallest: Test Accuracy = 0.928
# All models processed successfully!

# %% [markdown]
# ### TRM + TCN: 208 kb, 52.0 K parameters

# %%
from Model_Trainer import run_multiple_models
from Dataset_torch import EEGDataset_with_filters

from TRM import TRM_EEG_Model_v7_6
models = [TRM_EEG_Model_v7_6,]

shared_parameters_ssvep = {
    "data_path": "datasets/numpy/ssvep_4_nofilter_GMCGA_no01_4labels_250hz_1.5_window_size.npz",
    
    "DATASET_CLASS": EEGDataset_with_filters,
    
    "NOTCH_50": True,         
    "OCCIPITAL_SLICE": slice(0, 8), 
    
    "MAX_TIME": "00:02:00:00",
    "MODEL_KWARGS": {
        "in_channels": 8, 
        "num_classes": 4,
        "class_labels": [10.5, 12, 15.2, 18.1],
        "class_weights": [1.0, 1.0, 1.0, 1.0],
    },
    "SUMMARY": True,
    "skip_training": True,
    "LOAD_CHECKPOINT": "logs/TRM_EEG_Model_v7_6/version_3_987/checkpoints/best-8105-val_acc=0.970.ckpt",  
}
results, test_loader = run_multiple_models(models, shared_parameters_ssvep)
# Out:
# Loading data from: datasets/numpy/ssvep_4_nofilter_GMCGA_no01_4labels_250hz_1.5_window_size.npz
# Data loaded: X=(1576, 8, 375), y=(1576,)
# Dataset split: Train=1103, Val=236, Test=237
# Dataloaders ready
#
# Processing  TRM_EEG_Model_v7_6...
#
# Loading model from checkpoint instead of training:
#   logs/TRM_EEG_Model_v7_6/version_3_987/checkpoints/best-8105-val_acc=0.970.ckpt
#   | Name         | Type                              | Params | Mode
# ---------------------------------------------------------------------------
# 0 | loss_fn      | CrossEntropyLoss                  | 0      | train
# 1 | train_acc    | MulticlassAccuracy                | 0      | train
# 2 | val_acc      | MulticlassAccuracy                | 0      | train
# 3 | test_acc     | MulticlassAccuracy                | 0      | train
# 4 | test_cm      | MulticlassConfusionMatrix         | 0      | train
# 5 | encoder      | TCNModel_v1_outch64_GELU_head2_v7 | 43.3 K | train
# 6 | shared_net   | TRMSharedNet                      | 8.3 K  | train
# 7 | output_head  | Linear                            | 260    | train
# 8 | dropout      | Dropout                           | 0      | train
#   | other params | n/a                               | 128    | n/a
# ---------------------------------------------------------------------------
# 52.0 K    Trainable params
# 0         Non-trainable params
# 52.0 K    Total params
# 0.208     Total estimated model params size (MB)
# 27        Modules in train mode
# 0         Modules in eval mode
# Class 10.5 accuracy: 0.983
# Class 12 accuracy: 0.984
# Class 15.2 accuracy: 0.982
# Class 18.1 accuracy: 1.000
# TRM_EEG_Model_v7_6: Test accuracy = 0.987
#
# Plotting TRM_EEG_Model_v7_6: Test Accuracy = 0.987
# All models processed successfully!

# %% [markdown]
# # 4 SSVEP frequencies + “no-signal” class

# %% [markdown]
# ### Old Model 42 kb, 10.5 K parameters

# %%
from Model_Trainer import run_multiple_models
from Models_1D import TCNModel_withBase
from Dataset_torch import EEGDataset_with_filters

models = [
    TCNModel_withBase, 
]

shared_parameters_ssvep = { 
    "data_path": "datasets/numpy/ssvep_5_nofilter_GMCGA_no1_5labels_250hz_1.5_window_size_0.4keepratio.npz",   
    
    "DATASET_CLASS": EEGDataset_with_filters,
    
    "NOTCH_50": True,         
    "OCCIPITAL_SLICE": slice(0, 8), 
    
    "MAX_TIME": "00:00:01:00",
    "MODEL_KWARGS": {
        "in_channels": 8, 
        "num_classes": 5,
        "class_labels": [0, 10.5, 12.0, 15.2, 18.1],
        "class_weights": [0.5, 1.0, 1.0, 1.0, 1.0], 
    },
    
    "skip_training": True, 
    "LOAD_CHECKPOINT": "logs/TCNModel_withBase/version_54_5_retrained_best/checkpoints/best-11473-val_acc=0.865.ckpt"
}
results, test_loader = run_multiple_models(models, shared_parameters_ssvep)
# Out:
# Loading data from: datasets/numpy/ssvep_5_nofilter_GMCGA_no1_5labels_250hz_1.5_window_size_0.4keepratio.npz
# Data loaded: X=(2718, 8, 375), y=(2718,)
# Dataset split: Train=1902, Val=407, Test=409
# Dataloaders ready
#
# Processing  TCNModel_withBase...
#
# Loading model from checkpoint instead of training:
#   logs/TCNModel_withBase/version_54_5_retrained_best/checkpoints/best-11473-val_acc=0.865.ckpt
#   | Name      | Type                      | Params | Mode
# ----------------------------------------------------------------
# 0 | train_acc | MulticlassAccuracy        | 0      | train
# 1 | val_acc   | MulticlassAccuracy        | 0      | train
# 2 | test_acc  | MulticlassAccuracy        | 0      | train
# 3 | test_cm   | MulticlassConfusionMatrix | 0      | train
# 4 | tcn       | Sequential                | 10.4 K | train
# 5 | head      | Linear                    | 165    | train
# ----------------------------------------------------------------
# 10.5 K    Trainable params
# 0         Non-trainable params
# 10.5 K    Total params
# 0.042     Total estimated model params size (MB)
# 18        Modules in train mode
# 0         Modules in eval mode
# Class 0 accuracy: 0.779
# Class 10.5 accuracy: 0.922
# Class 12.0 accuracy: 0.800
# Class 15.2 accuracy: 0.863
# Class 18.1 accuracy: 0.873
# TCNModel_withBase: Test accuracy = 0.834
#
# Plotting TCNModel_withBase: Test Accuracy = 0.834
# All models processed successfully!

# %% [markdown]
# ### New Model 175 kb, 43.8 K parameters

# %%
from Model_Trainer import run_multiple_models
from Dataset_torch import EEGDataset_with_filters
from Models_1D import TCNModel_withBase, TCNModel_v1_outch64_GELU_head2

models = [
    TCNModel_v1_outch64_GELU_head2, 
]

shared_parameters_ssvep = { 
    "data_path": "datasets/numpy/ssvep_5_nofilter_GMCGA_no1_5labels_250hz_1.5_window_size_0.4keepratio.npz",   
    
    "DATASET_CLASS": EEGDataset_with_filters,
    
    "NOTCH_50": True,         
    "OCCIPITAL_SLICE": slice(0, 8), 
    
    "MAX_TIME": "00:00:01:00",
    "MODEL_KWARGS": {
        "in_channels": 8, 
        "num_classes": 5,
        "class_labels": [0, 10.5, 12.0, 15.2, 18.1],
        "class_weights": [0.5, 1.0, 1.0, 1.0, 1.0], 
    },
    
    "skip_training": True, 
    "LOAD_CHECKPOINT": "logs/TCNModel_v1_outch64_GELU_head2/version_5_5_890/checkpoints/best-11801-val_acc=0.894.ckpt"
}
results, test_loader = run_multiple_models(models, shared_parameters_ssvep)
# Out:
# Loading data from: datasets/numpy/ssvep_5_nofilter_GMCGA_no1_5labels_250hz_1.5_window_size_0.4keepratio.npz
# Data loaded: X=(2718, 8, 375), y=(2718,)
# Dataset split: Train=1902, Val=407, Test=409
# Dataloaders ready
#
# Processing  TCNModel_v1_outch64_GELU_head2...
#
# Loading model from checkpoint instead of training:
#   logs/TCNModel_v1_outch64_GELU_head2/version_5_5_890/checkpoints/best-11801-val_acc=0.894.ckpt
#   | Name      | Type                      | Params | Mode
# ----------------------------------------------------------------
# 0 | train_acc | MulticlassAccuracy        | 0      | train
# 1 | val_acc   | MulticlassAccuracy        | 0      | train
# 2 | test_acc  | MulticlassAccuracy        | 0      | train
# 3 | test_cm   | MulticlassConfusionMatrix | 0      | train
# 4 | tcn       | Sequential                | 39.2 K | train
# 5 | head      | Sequential                | 4.6 K  | train
# ----------------------------------------------------------------
# 43.8 K    Trainable params
# 0         Non-trainable params
# 43.8 K    Total params
# 0.175     Total estimated model params size (MB)
# 22        Modules in train mode
# 0         Modules in eval mode
# Class 0 accuracy: 0.799
# Class 10.5 accuracy: 0.953
# Class 12.0 accuracy: 0.967
# Class 15.2 accuracy: 0.918
# Class 18.1 accuracy: 0.937
# TCNModel_v1_outch64_GELU_head2: Test accuracy = 0.890
#
# Plotting TCNModel_v1_outch64_GELU_head2: Test Accuracy = 0.890
# All models processed successfully!

# %% [markdown]
# # 10 SSVEP frequencies

# %% [markdown]
# ### Old TCN 43 kb, 10.7 K parameters

# %%
from Model_Trainer import run_multiple_models
from Models_1D import TCNModel_withBase
from Dataset_torch import EEGDataset_with_filters

models = [
    TCNModel_withBase, 
]

shared_parameters_ssvep = {
    "data_path": "datasets/numpy/ssvep_10_nofilter_GMCGAGG_10labels_250hz_1.5_window_size.npz",  
    
    "DATASET_CLASS": EEGDataset_with_filters,
    
    "NOTCH_50": True,         
    "OCCIPITAL_SLICE": slice(0, 8), 
    
    "MAX_TIME": "00:00:01:00",
    "MODEL_KWARGS": {
        "in_channels": 8, 
        "num_classes": 10,
        "class_labels": [5.0, 7.0, 8.6, 10.5, 11.0, 12.0, 13.4, 15.2, 17.0, 18.1],
        "class_weights": [1.0, 1.0, 1.5, 1.0, 1.5, 1.0, 1.0, 1.0, 1.5, 1.0],
    },
    
    "skip_training": True, 
    # "LOAD_CHECKPOINT": "logs/TCNModel_withBase/version_49_10_balanced/checkpoints/best-580-val_acc=0.852.ckpt",   
    # "LOAD_CHECKPOINT": "logs/TCNModel_withBase/version_52_10_balanced/checkpoints/best-4880-val_acc=0.886.ckpt",
    "LOAD_CHECKPOINT": "logs/TCNModel_withBase/version_55_10_most_balanced_and_best/checkpoints/best-9786-val_acc=0.908.ckpt"
}
results, test_loader = run_multiple_models(models, shared_parameters_ssvep)
# Out:
# Loading data from: datasets/numpy/ssvep_10_nofilter_GMCGAGG_10labels_250hz_1.5_window_size.npz
# Data loaded: X=(2746, 8, 375), y=(2746,)
# Dataset split: Train=1922, Val=411, Test=413
# Dataloaders ready
#
# Processing  TCNModel_withBase...
#
# Loading model from checkpoint instead of training:
#   logs/TCNModel_withBase/version_55_10_most_balanced_and_best/checkpoints/best-9786-val_acc=0.908.ckpt
#   | Name      | Type                      | Params | Mode
# ----------------------------------------------------------------
# 0 | train_acc | MulticlassAccuracy        | 0      | train
# 1 | val_acc   | MulticlassAccuracy        | 0      | train
# 2 | test_acc  | MulticlassAccuracy        | 0      | train
# 3 | test_cm   | MulticlassConfusionMatrix | 0      | train
# 4 | tcn       | Sequential                | 10.4 K | train
# 5 | head      | Linear                    | 330    | train
# ----------------------------------------------------------------
# 10.7 K    Trainable params
# 0         Non-trainable params
# 10.7 K    Total params
# 0.043     Total estimated model params size (MB)
# 18        Modules in train mode
# 0         Modules in eval mode
# Class 5.0 accuracy: 0.844
# Class 7.0 accuracy: 0.930
# Class 8.6 accuracy: 0.913
# Class 10.5 accuracy: 1.000
# Class 11.0 accuracy: 0.680
# Class 12.0 accuracy: 0.879
# Class 13.4 accuracy: 1.000
# Class 15.2 accuracy: 0.930
# Class 17.0 accuracy: 0.880
# Class 18.1 accuracy: 0.944
# TCNModel_withBase: Test accuracy = 0.913
#
# Plotting TCNModel_withBase: Test Accuracy = 0.913
# All models processed successfully!

# %% [markdown]
# ### TCN smallest 11 kb, 2.8 K parameters

# %%
from Model_Trainer import run_multiple_models
from Random_models import TCNModel_v1_outch64_GELU_head2_smallest
from Dataset_torch import EEGDataset_with_filters

models = [
    TCNModel_v1_outch64_GELU_head2_smallest, 
]

shared_parameters_ssvep = {
    "data_path": "datasets/numpy/ssvep_10_nofilter_GMCGAGG_10labels_250hz_1.5_window_size.npz",  
    
    "DATASET_CLASS": EEGDataset_with_filters,
    
    "NOTCH_50": True,         
    "OCCIPITAL_SLICE": slice(0, 8), 
    
    "MAX_TIME": "00:01:00:00",
    "MODEL_KWARGS": {
        "in_channels": 8, 
        "num_classes": 10,
        "class_labels": [5.0, 7.0, 8.6, 10.5, 11.0, 12.0, 13.4, 15.2, 17.0, 18.1],
        "class_weights": [1.0, 1.0, 1.5, 1.0, 1.5, 1.0, 1.0, 1.0, 1.5, 1.0],
    },
    
    # "skip_training": True, 
    # "LOAD_CHECKPOINT": "logs/TCNModel_withBase/version_49_10_balanced/checkpoints/best-580-val_acc=0.852.ckpt",   
    # # "LOAD_CHECKPOINT": "logs/TCNModel_withBase/version_52_10_balanced/checkpoints/best-4880-val_acc=0.886.ckpt",
    # "LOAD_CHECKPOINT": "logs/TCNModel_withBase/version_55_10_most_balanced_and_best/checkpoints/best-9786-val_acc=0.908.ckpt"
    "LOAD_CHECKPOINT": "logs/TCNModel_v1_outch64_GELU_head2_smallest/version_2_10_743/checkpoints/best-23161-val_acc=0.810.ckpt"
}
results, test_loader = run_multiple_models(models, shared_parameters_ssvep)
# Out:
# Loading data from: datasets/numpy/ssvep_10_nofilter_GMCGAGG_10labels_250hz_1.5_window_size.npz
# Data loaded: X=(2746, 8, 375), y=(2746,)
# Dataset split: Train=1922, Val=411, Test=413
# Dataloaders ready
#
# Processing  TCNModel_v1_outch64_GELU_head2_smallest...
#
# Training TCNModel_v1_outch64_GELU_head2_smallest...
#
#   | Name      | Type                      | Params | Mode
# ----------------------------------------------------------------
# 0 | train_acc | MulticlassAccuracy        | 0      | train
# 1 | val_acc   | MulticlassAccuracy        | 0      | train
# 2 | test_acc  | MulticlassAccuracy        | 0      | train
# 3 | test_cm   | MulticlassConfusionMatrix | 0      | train
# 4 | tcn       | Sequential                | 1.5 K  | train
# 5 | head      | Sequential                | 1.2 K  | train
# ----------------------------------------------------------------
# 2.8 K     Trainable params
# 0         Non-trainable params
# 2.8 K     Total params
# 0.011     Total estimated model params size (MB)
# 31        Modules in train mode
# 0         Modules in eval mode
# Best model saved at: logs/TCNModel_v1_outch64_GELU_head2_smallest/version_3/checkpoints/best-8767-val_acc=0.832.ckpt
#   | Name      | Type                      | Params | Mode
# ----------------------------------------------------------------
# 0 | train_acc | MulticlassAccuracy        | 0      | train
# 1 | val_acc   | MulticlassAccuracy        | 0      | train
# 2 | test_acc  | MulticlassAccuracy        | 0      | train
# 3 | test_cm   | MulticlassConfusionMatrix | 0      | train
# 4 | tcn       | Sequential                | 1.5 K  | train
# 5 | head      | Sequential                | 1.2 K  | train
# ----------------------------------------------------------------
# 2.8 K     Trainable params
# 0         Non-trainable params
# 2.8 K     Total params
# 0.011     Total estimated model params size (MB)
# 31        Modules in train mode
# 0         Modules in eval mode
# Class 5.0 accuracy: 0.469
# Class 7.0 accuracy: 0.965
# Class 8.6 accuracy: 0.652
# Class 10.5 accuracy: 0.923
# Class 11.0 accuracy: 0.920
# Class 12.0 accuracy: 0.914
# Class 13.4 accuracy: 0.647
# Class 15.2 accuracy: 0.947
# Class 17.0 accuracy: 0.400
# Class 18.1 accuracy: 0.852
# TCNModel_v1_outch64_GELU_head2_smallest: Test accuracy = 0.828
#
# Plotting TCNModel_v1_outch64_GELU_head2_smallest: Test Accuracy = 0.828
# All models processed successfully!

# %% [markdown]
# ### TRM + TCN: 210 kb, 52.4 K parameters

# %%
from Model_Trainer import run_multiple_models
from TRM import TRM_EEG_Model_v7_6
from Dataset_torch import EEGDataset_with_filters

models = [
    TRM_EEG_Model_v7_6, 
]

shared_parameters_ssvep = {
    "data_path": "datasets/numpy/ssvep_10_nofilter_GMCGAGG_10labels_250hz_1.5_window_size.npz",  
    
    "DATASET_CLASS": EEGDataset_with_filters,
    
    "NOTCH_50": True,         
    "OCCIPITAL_SLICE": slice(0, 8), 
    
    "MAX_TIME": "00:02:00:00",
    "MODEL_KWARGS": {
        "in_channels": 8, 
        "num_classes": 10,
        "class_labels": [5.0, 7.0, 8.6, 10.5, 11.0, 12.0, 13.4, 15.2, 17.0, 18.1],
        "class_weights": [1.0, 1.0, 1.5, 1.0, 1.5, 1.0, 1.0, 1.0, 1.5, 1.0],
    },
    
    "skip_training": True, 
    "LOAD_CHECKPOINT": "logs/TRM_EEG_Model_v7_6/version_4_908_10ssvep/checkpoints/best-8358-val_acc=0.905.ckpt"
    
}
results, test_loader = run_multiple_models(models, shared_parameters_ssvep)
# Out:
# Loading data from: datasets/numpy/ssvep_10_nofilter_GMCGAGG_10labels_250hz_1.5_window_size.npz
# Data loaded: X=(2746, 8, 375), y=(2746,)
# Dataset split: Train=1922, Val=411, Test=413
# Dataloaders ready
#
# Processing  TRM_EEG_Model_v7_6...
#
# Loading model from checkpoint instead of training:
#   logs/TRM_EEG_Model_v7_6/version_4_908_10ssvep/checkpoints/best-8358-val_acc=0.905.ckpt
#   | Name         | Type                              | Params | Mode
# ---------------------------------------------------------------------------
# 0 | loss_fn      | CrossEntropyLoss                  | 0      | train
# 1 | train_acc    | MulticlassAccuracy                | 0      | train
# 2 | val_acc      | MulticlassAccuracy                | 0      | train
# 3 | test_acc     | MulticlassAccuracy                | 0      | train
# 4 | test_cm      | MulticlassConfusionMatrix         | 0      | train
# 5 | encoder      | TCNModel_v1_outch64_GELU_head2_v7 | 43.3 K | train
# 6 | shared_net   | TRMSharedNet                      | 8.3 K  | train
# 7 | output_head  | Linear                            | 650    | train
# 8 | dropout      | Dropout                           | 0      | train
#   | other params | n/a                               | 128    | n/a
# ---------------------------------------------------------------------------
# 52.4 K    Trainable params
# 0         Non-trainable params
# 52.4 K    Total params
# 0.210     Total estimated model params size (MB)
# 27        Modules in train mode
# 0         Modules in eval mode
# Class 5.0 accuracy: 0.906
# Class 7.0 accuracy: 0.860
# Class 8.6 accuracy: 0.913
# Class 10.5 accuracy: 0.938
# Class 11.0 accuracy: 0.920
# Class 12.0 accuracy: 0.810
# Class 13.4 accuracy: 1.000
# Class 15.2 accuracy: 0.895
# Class 17.0 accuracy: 1.000
# Class 18.1 accuracy: 0.963
# TRM_EEG_Model_v7_6: Test accuracy = 0.908
#
# Plotting TRM_EEG_Model_v7_6: Test Accuracy = 0.908
# All models processed successfully!

# %% [markdown]
# # PhysioNet imaginary motor movement (left vs right fist)

# %% [markdown]
# ### TCN 217 kb, 54.3 K parameters

# %%
from Model_Trainer import run_multiple_models
from Models_1D import TCNModel_v1_outch64_GELU_head2
from Dataset_torch import EEGDataset_with_filters_EDF_Stream

models = [TCNModel_v1_outch64_GELU_head2,]

shared_parameters_ssvep = {  
    "data_path": "/home/gtenzing/skyforge/ml_bci/week_4/dataset/files",
    "SUBJECTS": [s for s in range(1, 109) if s not in [38, 88, 89, 92, 100, 104]],
    "SAMPLE_RATE": 160,
    "RUNS": [4, 8, 12],
    "CLASSES": ["T1", "T2"],
    
    "DATASET_CLASS": EEGDataset_with_filters_EDF_Stream,
    
    "NOTCH_50": True,         
    "OCCIPITAL_SLICE": slice(0, 64), 
    "BATCH_SIZE": 32,
    "NUM_WORKERS": 11,
    "PREFETCH_FACTOR": 1,
    
    "MAX_TIME": "00:00:10:00",
    "MODEL_KWARGS": {
        "in_channels": 64, 
        "num_classes": 2,
        "class_labels": ["left_fist", "right_fist"],
    },
    
    "skip_training": True,
    "LOAD_CHECKPOINT": "logs/TCNModel_v1_outch64_GELU_head2/version_19_im_lr/checkpoints/best-13-val_acc=0.781.ckpt", 
}  
results, test_loader = run_multiple_models(models, shared_parameters_ssvep)
# Out:
# Loading data from: /home/gtenzing/skyforge/ml_bci/week_4/dataset/files
# Using label_map: {'T1': 0, 'T2': 1}
# Dataset split: Train=3213, Val=688, Test=689
# Dataloaders ready
#
# Processing  TCNModel_v1_outch64_GELU_head2...
#
# Loading model from checkpoint instead of training:
#   logs/TCNModel_v1_outch64_GELU_head2/version_19_im_lr/checkpoints/best-13-val_acc=0.781.ckpt
#   | Name      | Type                      | Params | Mode
# ----------------------------------------------------------------
# 0 | loss_fn   | CrossEntropyLoss          | 0      | train
# 1 | train_acc | MulticlassAccuracy        | 0      | train
# 2 | val_acc   | MulticlassAccuracy        | 0      | train
# 3 | test_acc  | MulticlassAccuracy        | 0      | train
# 4 | test_cm   | MulticlassConfusionMatrix | 0      | train
# 5 | tcn       | Sequential                | 49.9 K | train
# 6 | head      | Sequential                | 4.4 K  | train
# ----------------------------------------------------------------
# 54.3 K    Trainable params
# 0         Non-trainable params
# 54.3 K    Total params
# 0.217     Total estimated model params size (MB)
# 23        Modules in train mode
# 0         Modules in eval mode
# Class left_fist accuracy: 0.820
# Class right_fist accuracy: 0.706
# TCNModel_v1_outch64_GELU_head2: Test accuracy = 0.763
#
# Plotting TCNModel_v1_outch64_GELU_head2: Test Accuracy = 0.763
# All models processed successfully!

# %% [markdown]
# ### TinyRecursionModel with TCN_smal 172 kb, 42.9 K parameters

# %%
from Model_Trainer import run_multiple_models
from Dataset_torch import EEGDataset_with_filters_EDF_Stream
from TRM import TRM_EEG_Model_v1
models = [
    TRM_EEG_Model_v1,
]

shared_parameters_ssvep = {  
    "data_path": "/home/gtenzing/skyforge/ml_bci/week_4/dataset/files",
    "SUBJECTS": [s for s in range(1, 109) if s not in [38, 88, 89, 92, 100, 104]],
    "SAMPLE_RATE": 160,
    "RUNS": [4, 8, 12],
    "CLASSES": ["T1", "T2"],
    
    "DATASET_CLASS": EEGDataset_with_filters_EDF_Stream,
    "TRAIN_SPLIT": 0.7,
    "VAL_SPLIT": 0.20,
    "TEST_SPLIT": 0.10,
    
    "NOTCH_50": True,         
    "OCCIPITAL_SLICE": slice(0, 64), 
    "BATCH_SIZE": 32,
    "NUM_WORKERS": 11,
    "PREFETCH_FACTOR": 1,
    
    "MAX_TIME": "00:00:15:00",
    # "EPOCHS": 1,
    "MODEL_KWARGS": {
        "in_channels": 64, 
        "num_classes": 2,
        "class_labels": ["left_fist", "right_fist"],
    },
    
    "skip_training": True,
    "LOAD_CHECKPOINT": "logs/TRM_EEG_Model_v1/version_7_immv2_804_v1/checkpoints/best-21-val_acc=0.796.ckpt",    # 15min 
}    
results, test_loader = run_multiple_models(models, shared_parameters_ssvep)
# Out:
# Loading data from: /home/gtenzing/skyforge/ml_bci/week_4/dataset/files
# Using label_map: {'T1': 0, 'T2': 1}
# Dataset split: Train=3213, Val=918, Test=459
# Dataloaders ready
#
# Processing  TRM_EEG_Model_v1...
#
# Loading model from checkpoint instead of training:
#   logs/TRM_EEG_Model_v1/version_7_immv2_804_v1/checkpoints/best-21-val_acc=0.796.ckpt
#   | Name         | Type                                 | Params | Mode
# ------------------------------------------------------------------------------
# 0 | loss_fn      | CrossEntropyLoss                     | 0      | train
# 1 | train_acc    | MulticlassAccuracy                   | 0      | train
# 2 | val_acc      | MulticlassAccuracy                   | 0      | train
# 3 | test_acc     | MulticlassAccuracy                   | 0      | train
# 4 | test_cm      | MulticlassConfusionMatrix            | 0      | train
# 5 | encoder      | TCNModel_v1_outch64_GELU_head2_small | 9.4 K  | train
# 6 | shared_net   | TRMSharedNet                         | 33.0 K | train
# 7 | output_head  | Linear                               | 258    | train
#   | other params | n/a                                  | 256    | n/a
# ------------------------------------------------------------------------------
# 42.9 K    Trainable params
# 0         Non-trainable params
# 42.9 K    Total params
# 0.172     Total estimated model params size (MB)
# 32        Modules in train mode
# 0         Modules in eval mode
# Class left_fist accuracy: 0.850
# Class right_fist accuracy: 0.759
# TRM_EEG_Model_v1: Test accuracy = 0.804
#
# Plotting TRM_EEG_Model_v1: Test Accuracy = 0.804
# All models processed successfully!
